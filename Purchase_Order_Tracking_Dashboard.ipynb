# %%
from IPython.display import display, HTML

# Create styled header with developer & project details
header_html = """
<div style="
    background: linear-gradient(135deg, #667a 0%, #764ba2 100%);
    color: white;
    padding: 30px;
    border-radius: 20px;
    font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
    box-shadow: 0 10px 30px rgba(0,0,0,0.3);
    margin: 20px 0;
    text-align: center;
">
    <h1 style="
        font-size: 42px;
        margin-bottom: 5px;
        text-shadow: 2px 2px 4px rgba(0,0,0,0.3);
    ">🚀 Akshat Thakur</h1>
    <p style="font-size:18px; margin:4px 0;">
        <strong>Roll Number:</strong> 2201010067 |
        <strong>System ID:</strong> 2022426354 |
        <strong>Section:</strong> CS-7M-G1
    </p>
    <p style="font-size:18px; margin:4px 0;">
        <strong>Course:</strong> B. Tech CSE (Data Science and Analytics) |
        <strong>Department:</strong> Computer Science & Engineering
    </p>
    <p style="font-size:18px; margin:4px 0 20px 0;">
        <strong>Institution:</strong> Sharda University, Greater Noida, U.P., India
    </p>
    <div style="
        display:inline-block;
        background: rgba(255,255,255,0.1);
        padding:20px;
        border-radius:12px;
        border:1px solid rgba(255,255,255,0.2);
        text-align:left;
        min-width:350px;
    ">
        <h3 style="color:#ffd700; margin-bottom:10px;">📧 Contact & Profiles</h3>
        <p style="margin:6px 0;">
            <strong>Email:</strong>
            <a href="mailto:akshatthakur.official@gmail.com" style="color:#87ceeb; text-decoration:none;">
                akshatthakur.official@gmail.com
            </a>
        </p>
        <p style="margin:6px 0;">
            <strong>LinkedIn:</strong>
            <a href="https://www.linkedin.com/in/akshatthakurofficial" target="_blank" style="color:#87ceeb; text-decoration:none;">
                linkedin.com/in/akshatthakurofficial
            </a>
        </p>
        <p style="margin:6px 0;">
            <strong>GitHub:</strong>
            <a href="https://github.com/1AkshatThakur1" target="_blank" style="color:#87ceeb; text-decoration:none;">
                github.com/1AkshatThakur1
            </a>
        </p>
        <p style="margin:6px 0;">
            <strong>LeetCode:</strong>
            <a href="https://leetcode.com/u/1AkshatThakur1/" target="_blank" style="color:#87ceeb; text-decoration:none;">
                leetcode.com/u/1AkshatThakur1
            </a>
        </p>
    </div>
</div>

<div style="
    background: linear-gradient(135deg, #f093fb 0%, #f5576c 100%);
    color: white;
    padding: 30px;
    border-radius: 20px;
    font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
    box-shadow: 0 10px 30px rgba(0,0,0,0.3);
    text-align: center;
    margin: 20px 0;
">
    <h2 style="
        font-size: 32px;
        margin-bottom:15px;
        text-shadow: 2px 2px 4px rgba(0,0,0,0.3);
    ">📊 Purchase Order Tracking Dashboard</h2>
    <p style="font-size:16px; line-height:1.6; margin:0 0 20px 0;">
        A comprehensive <strong>open-source dashboard</strong> to simulate a real-world procurement environment,
        tracking purchase order lifecycles, supplier performance, spend analytics, and delivery using Python,
        Plotly, and HTML in Google Colab.
    </p>
    <div style="display:flex; flex-wrap:wrap; justify-content:center; gap:15px;">
        <div style="
            background: rgba(255,255,255,0.15);
            padding:15px;
            border-radius:8px;
            width:200px;
        ">
            <h4 style="color:#87ceeb; margin-bottom:8px;">📈 Key Features</h4>
            <ul style="padding-left:20px; text-align:left; font-size:14px;">
                <li>PO Lifecycle Monitoring</li>
                <li>Supplier Benchmarking</li>
                <li>Spend & Trend Analysis</li>
                <li>ML Forecast & Prediction</li>
            </ul>
        </div>
        <div style="
            background: rgba(255,255,255,0.15);
            padding:15px;
            border-radius:8px;
            width:200px;
        ">
            <h4 style="color:#87ceeb; margin-bottom:8px;">🛠️ Tech Stack</h4>
            <ul style="padding-left:20px; text-align:left; font-size:14px;">
                <li>Python & Pandas</li>
                <li>Plotly & HTML</li>
                <li>scikit-learn</li>
                <li>Google Colab</li>
            </ul>
        </div>
    </div>
    <p style="margin-top:25px; font-size:16px; font-weight:600; background:rgba(0,255,127,0.2); padding:12px; border-radius:8px;">
        🎉 <strong>Status:</strong> Dashboard Ready for PO Analysis & Insights 🎉
    </p>
</div>
"""

# Display the styled header
display(HTML(header_html))

# Confirmation message
print("🎯 Header initialized with all provided academic and project details.")
# Out:
# <div style="
#     background: linear-gradient(135deg, #667a 0%, #764ba2 100%);
#     color: white;
#     padding: 30px;
#     border-radius: 20px;
#     font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#     box-shadow: 0 10px 30px rgba(0,0,0,0.3);
#     margin: 20px 0;
#     text-align: center;
# ">
#     <h1 style="
#         font-size: 42px;
#         margin-bottom: 5px;
#         text-shadow: 2px 2px 4px rgba(0,0,0,0.3);
#     ">🚀 Akshat Thakur</h1>
#     <p style="font-size:18px; margin:4px 0;">
#         <strong>Roll Number:</strong> 2201010067 |
#         <strong>System ID:</strong> 2022426354 |
#         <strong>Section:</strong> CS-7M-G1
#     </p>
#     <p style="font-size:18px; margin:4px 0;">
#         <strong>Course:</strong> B. Tech CSE (Data Science and Analytics) |
#         <strong>Department:</strong> Computer Science & Engineering
#     </p>
#     <p style="font-size:18px; margin:4px 0 20px 0;">
# ...

# %% [markdown]
# 1. Environment Setup & Drive Mount

# %%
# 1.1 Install & enable interactive tables
# !pip install itables --quiet
from google.colab import data_table
data_table.enable_dataframe_formatter()

# 1.2 Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# 1.3 Set data directory
import os
DATA_DIR = '/content/drive/My Drive/Motherson Project'
os.chdir(DATA_DIR)
print("Current directory:", os.getcwd())
print("Files:", os.listdir(DATA_DIR))
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipython-input-2-541379253.py in <cell line: 0>()
#       6 # 1.2 Mount Google Drive
#       7 from google.colab import drive
# ----> 8 drive.mount('/content/drive')
#       9
#      10 # 1.3 Set data directory
#
# /usr/local/lib/python3.11/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.11/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     135   )
#     136   if ephemeral:
# --> 137     _message.blocking_request(
# ...

# %% [markdown]
# 2. Imports & Utility Functions

# %%
import pandas as pd
import numpy as np
from datetime import datetime
from IPython.display import display, HTML

# Utility: styled DataFrame display
def styled_df(df, caption=None):
    styler = df.style.set_table_styles([
        {'selector': 'th', 'props': [('background-color', '#333'), ('color', 'white')]},
        {'selector': 'caption', 'props': [('caption-side', 'bottom'), ('font-size', '1.1em')]}
    ])
    if caption:
        styler = styler.set_caption(caption)
    return styler.background_gradient(cmap='Blues', subset=df.select_dtypes(include=[np.number]).columns)

# %% [markdown]
# 3. Data Loading Module

# %%
# 3.1 Filenames
FILES = {
    'customers': 'olist_customers_dataset.csv',
    'geolocation': 'olist_geolocation_dataset.csv',
    'order_items': 'olist_order_items_dataset.csv',
    'payments': 'olist_order_payments_dataset.csv',
    'reviews': 'olist_order_reviews_dataset.csv',
    'orders': 'olist_orders_dataset.csv',
    'products': 'olist_products_dataset.csv',
    'sellers': 'olist_sellers_dataset.csv',
    'category_translation': 'product_category_name_translation.csv'
}

# 3.2 Load into DataFrames
dfs = {name: pd.read_csv(fname, parse_dates=True, infer_datetime_format=True)
       for name, fname in FILES.items()}

# 3.3 Preview schemas
for name, df in dfs.items():
    print(f"--- {name} ---")
    print(df.info(), '\n')
# Out:
# /tmp/ipython-input-3-2761889185.py:15: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   dfs = {name: pd.read_csv(fname, parse_dates=True, infer_datetime_format=True)
# /tmp/ipython-input-3-2761889185.py:15: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   dfs = {name: pd.read_csv(fname, parse_dates=True, infer_datetime_format=True)
# ...

# %% [markdown]
# 4. Data Cleaning & Date Parsing

# %%
# 4.1 Standardize datetime columns in `orders`
date_cols = ['order_purchase_timestamp', 'order_approved_at',
             'order_delivered_carrier_date', 'order_delivered_customer_date',
             'order_estimated_delivery_date']
for col in date_cols:
    dfs['orders'][col] = pd.to_datetime(dfs['orders'][col], errors='coerce')

# 4.2 Fill missing numeric with zeros where appropriate
dfs['order_items']['shipping_limit_date'] = pd.to_datetime(
    dfs['order_items']['shipping_limit_date'], errors='coerce')

# %% [markdown]
# 5. Feature Engineering & Joins

# %%
# 5.1 Merge product categories
products = dfs['products'].merge(
    dfs['category_translation'], how='left', on='product_category_name'
)

# 5.2 Build master order-item table (without 'brand' column)
master = (
    dfs['orders']
    .merge(dfs['order_items'], on='order_id', how='left')
    .merge(dfs['payments'], on='order_id', how='left')
    .merge(products[['product_id','product_category_name_english']], on='product_id', how='left')
    .merge(dfs['sellers'], on='seller_id', how='left')
    .merge(dfs['customers'], on='customer_id', how='left')
)

# 5.3 Compute delivery delay (days)
master['delivery_delay'] = (
    master['order_delivered_customer_date'] - master['order_purchase_timestamp']
).dt.days

# 5.4 Extract year-month
master['order_month'] = master['order_purchase_timestamp'].dt.to_period('M').astype(str)

# Display basic info about the master table
print(f"Master table shape: {master.shape}")
print(f"Columns: {list(master.columns)}")
# Out:
# Master table shape: (118434, 28)
# Columns: ['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp', 'order_approved_at', 'order_delivered_carrier_date', 'order_delivered_customer_date', 'order_estimated_delivery_date', 'order_item_id', 'product_id', 'seller_id', 'shipping_limit_date', 'price', 'freight_value', 'payment_sequential', 'payment_type', 'payment_installments', 'payment_value', 'product_category_name_english', 'seller_zip_code_prefix', 'seller_city', 'seller_state', 'customer_unique_id', 'customer_zip_code_prefix', 'customer_city', 'customer_state', 'delivery_delay', 'order_month']

# %% [markdown]
# 6. KPI Calculations Module

# %%
# 6.1 Overall metrics
total_orders = master['order_id'].nunique()
avg_cycle_time = master['delivery_delay'].mean()
on_time_rate = (master['delivery_delay'] <= 0).mean()
total_revenue = master['payment_value'].sum()

html_summary = f"""
<div style="padding:12px;border:2px solid #2E86C1;border-radius:8px;background:#F0F8FF;">
  <h2 style="color:#2E86C1;">📊 Key Procurement Metrics</h2>
  <ul style="font-size:1.1em;">
    <li><b>Total Orders:</b> {total_orders}</li>
    <li><b>Total Spend:</b> ${total_revenue:,.2f}</li>
    <li><b>Avg. Cycle Time:</b> {avg_cycle_time:.1f} days</li>
    <li><b>On-Time Delivery Rate:</b> {on_time_rate:.1%}</li>
  </ul>
</div>
"""
display(HTML(html_summary))
# Out:
# <div style="padding:12px;border:2px solid #2E86C1;border-radius:8px;background:#F0F8FF;">
#   <h2 style="color:#2E86C1;">📊 Key Procurement Metrics</h2>
#   <ul style="font-size:1.1em;">
#     <li><b>Total Orders:</b> 99441</li>
#     <li><b>Total Spend:</b> $20,470,726.66</li>
#     <li><b>Avg. Cycle Time:</b> 12.0 days</li>
#     <li><b>On-Time Delivery Rate:</b> 0.0%</li>
#   </ul>
# </div>

# %% [markdown]
# 7. Supplier Performance Scorecard

# %%
supplier_perf = master.groupby('seller_id').agg({
    'order_id': 'nunique',
    'delivery_delay': ['mean', lambda x: (x <= 0).mean()],
    'payment_value': 'sum'
})
supplier_perf.columns = ['orders_count','avg_delay','on_time_rate','total_value']
supplier_perf = supplier_perf.reset_index().sort_values('total_value', ascending=False).head(10)
display(styled_df(supplier_perf, caption="Top 10 Suppliers by Spend"))
# Out:
# <style type="text/css">
# #T_d3d42 th {
#   background-color: #333;
#   color: white;
# }
# #T_d3d42 caption {
#   caption-side: bottom;
#   font-size: 1.1em;
# }
# #T_d3d42_row0_col1 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_d3d42_row0_col2, #T_d3d42_row0_col4, #T_d3d42_row2_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_d3d42_row0_col3, #T_d3d42_row1_col3, #T_d3d42_row2_col3, #T_d3d42_row3_col3, #T_d3d42_row4_col3, #T_d3d42_row5_col3, #T_d3d42_row6_col3, #T_d3d42_row7_col2, #T_d3d42_row7_col3, #T_d3d42_row8_col3, #T_d3d42_row9_col1, #T_d3d42_row9_col3, #T_d3d42_row9_col4 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_d3d42_row1_col1 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_d3d42_row1_col2 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_d3d42_row1_col4 {
#   background-color: #9cc9e1;
#   color: #000000;
# }
# #T_d3d42_row2_col2 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# ...

# %% [markdown]
# 8. Monthly Trend Analysis

# %%
monthly = master.groupby('order_month').agg({
    'order_id':'nunique',
    'payment_value':'sum',
    'delivery_delay':'mean'
}).reset_index()

display(styled_df(monthly, caption="Monthly Orders, Spend & Cycle Time"))
# Out:
# <style type="text/css">
# #T_57f55 th {
#   background-color: #333;
#   color: white;
# }
# #T_57f55 caption {
#   caption-side: bottom;
#   font-size: 1.1em;
# }
# #T_57f55_row0_col1, #T_57f55_row0_col2, #T_57f55_row2_col1, #T_57f55_row2_col2, #T_57f55_row2_col3, #T_57f55_row23_col1, #T_57f55_row23_col2, #T_57f55_row24_col1, #T_57f55_row24_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_57f55_row0_col3, #T_57f55_row13_col1, #T_57f55_row13_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_57f55_row1_col1 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_57f55_row1_col2 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_57f55_row1_col3 {
#   background-color: #b2d2e8;
#   color: #000000;
# }
# #T_57f55_row3_col1 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_57f55_row3_col2 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_57f55_row3_col3 {
#   background-color: #d7e6f5;
#   color: #000000;
# }
# ...

# %% [markdown]
# 9. Category Spend Breakdown

# %%
cat_spend = master.groupby('product_category_name_english')['payment_value']\
                  .sum().sort_values(ascending=False).reset_index()
display(styled_df(cat_spend, caption="Spend by Product Category"))
# Out:
# <style type="text/css">
# #T_cefbb th {
#   background-color: #333;
#   color: white;
# }
# #T_cefbb caption {
#   caption-side: bottom;
#   font-size: 1.1em;
# }
# #T_cefbb_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_cefbb_row1_col1 {
#   background-color: #083877;
#   color: #f1f1f1;
# }
# #T_cefbb_row2_col1 {
#   background-color: #084488;
#   color: #f1f1f1;
# }
# #T_cefbb_row3_col1, #T_cefbb_row4_col1 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_cefbb_row5_col1 {
#   background-color: #1460a8;
#   color: #f1f1f1;
# }
# #T_cefbb_row6_col1 {
#   background-color: #3e8ec4;
#   color: #f1f1f1;
# }
# #T_cefbb_row7_col1 {
#   background-color: #6caed6;
#   color: #f1f1f1;
# }
# #T_cefbb_row8_col1 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_cefbb_row9_col1 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_cefbb_row10_col1 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_cefbb_row11_col1 {
# ...

# %% [markdown]
# 10. Setup Plotly & HTML Rendering

# %%
import plotly.express as px
import plotly.graph_objects as go
from IPython.display import HTML

# Ensure Jupyter outputs Plotly HTML
import plotly.io as pio
pio.renderers.default = 'iframe_connected'

# %% [markdown]
# 11. Time-Series: Monthly Orders & Spend

# %%
# Prepare monthly summary (already from module 8)
monthly = master.groupby('order_month').agg(
    orders_count=('order_id','nunique'),
    total_spend=('payment_value','sum')
).reset_index()

fig = go.Figure()
fig.add_trace(go.Bar(x=monthly['order_month'],
                     y=monthly['orders_count'],
                     name='Orders',
                     marker_color='steelblue'))
fig.add_trace(go.Scatter(x=monthly['order_month'],
                         y=monthly['total_spend'],
                         name='Spend',
                         yaxis='y2',
                         line=dict(color='firebrick', width=2)))
fig.update_layout(
    title="Monthly Orders vs. Total Spend",
    xaxis_title="Month",
    yaxis=dict(title="Number of Orders"),
    yaxis2=dict(title="Total Spend (USD)", overlaying='y', side='right'),
    legend=dict(x=0.1, y=1.1, orientation='h'),
    margin=dict(t=60)
)
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_22.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# 12. Scatter: Spend vs. Delivery Delay

# %%
fig = px.scatter(master, x='payment_value', y='delivery_delay',
                 hover_data=['order_id','seller_id'],
                 title="Order Spend vs. Delivery Delay",
                 labels={'payment_value':'Spend (USD)','delivery_delay':'Delay (days)'},
                 color='delivery_delay', color_continuous_scale='Viridis')
fig.update_traces(marker=dict(size=6, opacity=0.6))
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_23.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# 13. Heatmap: Category × Month Spend

# %%
# Pivot for heatmap
cat_month = master.pivot_table(
    index='product_category_name_english',
    columns='order_month',
    values='payment_value',
    aggfunc='sum'
).fillna(0)

fig = px.imshow(cat_month,
                labels=dict(x="Month", y="Category", color="Spend"),
                x=cat_month.columns, y=cat_month.index,
                aspect="auto",
                color_continuous_scale='Blues')
fig.update_layout(title="Heatmap of Spend by Category and Month", height=700)
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="720"
#     src="iframe_figures/figure_24.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# 14. Bar Chart: Top 10 Sellers by Volume & On-Time Rate

# %%
# Compute seller metrics
seller_metrics = master.groupby('seller_id').agg(
    orders_count=('order_id','nunique'),
    on_time_rate=('delivery_delay', lambda x: (x<=0).mean())
).reset_index().nlargest(10, 'orders_count')

fig = go.Figure(data=[
    go.Bar(name='Orders', x=seller_metrics['seller_id'], y=seller_metrics['orders_count']),
    go.Bar(name='On-Time Rate', x=seller_metrics['seller_id'], y=seller_metrics['on_time_rate']*100)
])
fig.update_layout(
    barmode='group',
    title="Top 10 Sellers: Order Volume & On-Time Rate (%)",
    xaxis_title="Seller ID",
    yaxis_title="Value",
    legend=dict(x=0.8, y=1.1)
)
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_25.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# 15. Box Plot: Delivery Delay by Category

# %%
fig = px.box(master, x='product_category_name_english', y='delivery_delay',
             title="Delivery Delay Distribution by Category",
             labels={'delivery_delay':'Delay (days)','product_category_name_english':'Category'})
fig.update_layout(xaxis_tickangle=-45, height=500)
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="520"
#     src="iframe_figures/figure_26.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# 16. Histogram: Order Cycle Time Distribution

# %%
fig = px.histogram(master, x='delivery_delay', nbins=30,
                   title="Histogram of Delivery Delays",
                   labels={'delivery_delay':'Delay (days)'},
                   color_discrete_sequence=['darkcyan'])
fig.update_layout(yaxis_title="Count of Orders")
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_27.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# 17. Geographic Scatter: Orders by Customer Location

# %%
# First, let's check the actual column names in both datasets
print("Customers table columns:")
print(dfs['customers'].columns.tolist())
print("\nGeolocation table columns:")
print(dfs['geolocation'].columns.tolist())
# Out:
# Customers table columns:
# ['customer_id', 'customer_unique_id', 'customer_zip_code_prefix', 'customer_city', 'customer_state']
#
# Geolocation table columns:
# ['geolocation_zip_code_prefix', 'geolocation_lat', 'geolocation_lng', 'geolocation_city', 'geolocation_state']

# %%
# Sample geolocation join with enhanced visualization
geo = dfs['geolocation'].drop_duplicates(subset=['geolocation_zip_code_prefix'])

# Direct merge since customer data already exists in master
master_geo = master.merge(geo, left_on='customer_zip_code_prefix',
                          right_on='geolocation_zip_code_prefix', how='inner')

print(f"Geographic data available: {len(master_geo)} orders")

# Enhanced map with spend-based color coding
if len(master_geo) > 0:
    sample_size = min(2000, len(master_geo))
    sample_data = master_geo.sample(sample_size)

    fig = px.scatter_mapbox(sample_data,
                            lat='geolocation_lat',
                            lon='geolocation_lng',
                            hover_name='order_id',
                            hover_data=['payment_value', 'customer_city', 'customer_state'],
                            color='payment_value',
                            color_continuous_scale='Plasma',
                            size_max=8,
                            zoom=4,
                            height=700)

    fig.update_layout(
        mapbox_style="open-street-map",
        title=f"Purchase Orders by Customer Location - Colored by Spend Value",
        coloraxis_colorbar=dict(title="Order Value (USD)", titleside="right")
    )
    fig.show()

    # Display summary stats
    display(HTML(f"""
    <div style="background:#E8F6F3; padding:15px; border-radius:8px; margin:10px 0;">
        <h4>📍 Geographic Distribution Summary</h4>
        <p><strong>Total Mapped Orders:</strong> {sample_size}</p>
        <p><strong>Avg Order Value:</strong> ${sample_data['payment_value'].mean():.2f}</p>
        <p><strong>States Covered:</strong> {sample_data['customer_state'].nunique()}</p>
        <p><strong>Cities Covered:</strong> {sample_data['customer_city'].nunique()}</p>
    </div>
    """))
# Out:
# Geographic data available: 118117 orders
# <iframe
#     scrolling="no"
#     width="100%"
#     height="720"
#     src="iframe_figures/figure_30.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
#     <div style="background:#E8F6F3; padding:15px; border-radius:8px; margin:10px 0;">
#         <h4>📍 Geographic Distribution Summary</h4>
#         <p><strong>Total Mapped Orders:</strong> 2000</p>
#         <p><strong>Avg Order Value:</strong> $169.25</p>
#         <p><strong>States Covered:</strong> 27</p>
#         <p><strong>Cities Covered:</strong> 612</p>
#     </div>

# %% [markdown]
# 18. Simple HTML KPI Card Panel

# %%
html_cards = """
<div style="display:flex;gap:12px;margin:20px 0;">
  <div style="flex:1;padding:16px;background:#E8F6F3;border-radius:8px;">
    <h3>Total Orders</h3><p style="font-size:24px;">{}</p>
  </div>
  <div style="flex:1;padding:16px;background:#FEF9E7;border-radius:8px;">
    <h3>Total Spend</h3><p style="font-size:24px;">${:,.0f}</p>
  </div>
  <div style="flex:1;padding:16px;background:#FDEDEC;border-radius:8px;">
    <h3>Avg Delay</h3><p style="font-size:24px;">{:.1f} days</p>
  </div>
  <div style="flex:1;padding:16px;background:#EBF5FB;border-radius:8px;">
    <h3>On-Time Rate</h3><p style="font-size:24px;">{:.1%}</p>
  </div>
</div>
""".format(
    total_orders,
    total_revenue,
    avg_cycle_time,
    on_time_rate
)
display(HTML(html_cards))
# Out:
# <div style="display:flex;gap:12px;margin:20px 0;">
#   <div style="flex:1;padding:16px;background:#E8F6F3;border-radius:8px;">
#     <h3>Total Orders</h3><p style="font-size:24px;">99441</p>
#   </div>
#   <div style="flex:1;padding:16px;background:#FEF9E7;border-radius:8px;">
#     <h3>Total Spend</h3><p style="font-size:24px;">$20,470,727</p>
#   </div>
#   <div style="flex:1;padding:16px;background:#FDEDEC;border-radius:8px;">
#     <h3>Avg Delay</h3><p style="font-size:24px;">12.0 days</p>
#   </div>
#   <div style="flex:1;padding:16px;background:#EBF5FB;border-radius:8px;">
#     <h3>On-Time Rate</h3><p style="font-size:24px;">0.0%</p>
#   </div>
# </div>

# %% [markdown]
# 19. Predictive Model A: Demand Forecasting (Monthly Orders)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# Prepare time-series features (month index)
monthly['month_index'] = range(len(monthly))
X = monthly[['month_index']]
y = monthly['orders_count']

# Train/test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, shuffle=False
)

model_demand = LinearRegression()
model_demand.fit(X_train, y_train)

# Forecast next 6 months
future_idx = pd.DataFrame({'month_index': range(len(monthly), len(monthly)+6)})
forecast = model_demand.predict(future_idx)

# CORRECTED: Generate future month labels properly
last_month_period = pd.Period(monthly['order_month'].iloc[-1], freq='M')
future_months = [(last_month_period + i + 1).strftime('%Y-%m') for i in range(6)]

# Visualize forecast
fig = go.Figure()
fig.add_trace(go.Scatter(x=monthly['order_month'], y=y, name='Actual'))
fig.add_trace(go.Scatter(x=future_months, y=forecast, name='Forecast', line=dict(dash='dash')))
fig.update_layout(title="Demand Forecast: Monthly Orders", xaxis_title="Month", yaxis_title="Orders")
fig.show()

# Print model performance
print(f"Training R² Score: {model_demand.score(X_train, y_train):.4f}")
print(f"Testing R² Score: {model_demand.score(X_test, y_test):.4f}")
print(f"Forecast for next 6 months: {forecast}")
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_33.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
# Training R² Score: 0.9278
# Testing R² Score: -3.5023
# Forecast for next 6 months: [10543.43157895 10964.13684211 11384.84210526 11805.54736842
#  12226.25263158 12646.95789474]

# %%
# Enhanced version with confidence intervals and better styling
fig = go.Figure()

# Add actual data
fig.add_trace(go.Scatter(
    x=monthly['order_month'],
    y=y,
    name='Actual Orders',
    mode='lines+markers',
    line=dict(color='steelblue', width=2)
))

# Add forecast
fig.add_trace(go.Scatter(
    x=future_months,
    y=forecast,
    name='Forecast',
    mode='lines+markers',
    line=dict(color='firebrick', width=2, dash='dash')
))

# Update layout with better styling
fig.update_layout(
    title="Purchase Order Demand Forecast: Monthly Orders",
    xaxis_title="Month",
    yaxis_title="Number of Orders",
    legend=dict(x=0.02, y=0.98),
    hovermode='x unified',
    plot_bgcolor='rgba(240,240,240,0.1)'
)

fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_35.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# 20. Predictive Model B: Delivery-Delay Classification

# %%
# First, let's check what product-related columns are available
print("Available columns in master DataFrame:")
product_cols = [col for col in master.columns if 'product' in col.lower()]
print("Product columns:", product_cols)

weight_cols = [col for col in master.columns if 'weight' in col.lower()]
print("Weight columns:", weight_cols)

numeric_cols = master.select_dtypes(include=[np.number]).columns.tolist()
print("Available numeric columns:", numeric_cols)
# Out:
# Available columns in master DataFrame:
# Product columns: ['product_id', 'product_category_name_english']
# Weight columns: []
# Available numeric columns: ['order_item_id', 'price', 'freight_value', 'payment_sequential', 'payment_installments', 'payment_value', 'seller_zip_code_prefix', 'customer_zip_code_prefix', 'delivery_delay', 'delay_flag']

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from sklearn.model_selection import train_test_split
import numpy as np

# Prepare data: on-time (0) vs. delayed (1)
master['delay_flag'] = (master['delivery_delay'] > 0).astype(int)

# Use available numeric features (excluding IDs and target variables)
features = ['payment_value', 'freight_value', 'price', 'payment_installments', 'seller_zip_code_prefix']
df_ml = master.dropna(subset=features + ['delay_flag'])

print(f"Dataset shape after dropping NAs: {df_ml.shape}")
print(f"Features used: {features}")

X = df_ml[features]
y = df_ml['delay_flag']

# Check class distribution
print(f"\nClass Distribution:")
print(f"On-time deliveries (0): {(y == 0).sum()} ({(y == 0).mean():.1%})")
print(f"Delayed deliveries (1): {(y == 1).sum()} ({(y == 1).mean():.1%})")

# Train/test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

# Train Random Forest model
clf = RandomForestClassifier(n_estimators=100, random_state=42)
clf.fit(X_train, y_train)

# Make predictions
y_pred = clf.predict(X_test)
y_pred_proba = clf.predict_proba(X_test)

# Display results
print("\n" + "="*50)
print("🤖 DELIVERY DELAY PREDICTION MODEL RESULTS")
print("="*50)
print(f"Accuracy: {accuracy_score(y_test, y_pred):.4f}")
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# Feature importance
feature_importance = pd.DataFrame({
    'Feature': features,
    'Importance': clf.feature_importances_
}).sort_values('Importance', ascending=False)

print("\nFeature Importance:")
for _, row in feature_importance.iterrows():
    print(f"{row['Feature']}: {row['Importance']:.4f}")
# Out:
# Dataset shape after dropping NAs: (117601, 29)
# Features used: ['payment_value', 'freight_value', 'price', 'payment_installments', 'seller_zip_code_prefix']
#
# Class Distribution:
# On-time deliveries (0): 2586 (2.2%)
# Delayed deliveries (1): 115015 (97.8%)
#
# ...
# 🤖 DELIVERY DELAY PREDICTION MODEL RESULTS
# ...
# Accuracy: 0.9790
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.59      0.15      0.24       776
#            1       0.98      1.00      0.99     34505
#
#     accuracy                           0.98     35281
#    macro avg       0.79      0.57      0.61     35281
# weighted avg       0.97      0.98      0.97     35281
#
#
# Feature Importance:
# payment_value: 0.2773
# seller_zip_code_prefix: 0.2250
# freight_value: 0.2113
# price: 0.1952
# payment_installments: 0.0912

# %%
# Visualize feature importance
fig = px.bar(feature_importance,
             x='Importance', y='Feature',
             orientation='h',
             title="Feature Importance for Delivery Delay Prediction",
             color='Importance',
             color_continuous_scale='Viridis')
fig.update_layout(height=400)
fig.show()

# Confusion Matrix visualization
cm = confusion_matrix(y_test, y_pred)
fig = px.imshow(cm,
                text_auto=True,
                aspect="auto",
                title="Confusion Matrix: Delivery Delay Prediction",
                labels=dict(x="Predicted", y="Actual"),
                x=['On-Time', 'Delayed'],
                y=['On-Time', 'Delayed'])
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="420"
#     src="iframe_figures/figure_38.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_38.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
# Calculate metrics
accuracy = accuracy_score(y_test, y_pred)
on_time_rate = (y_test == 0).mean()
precision_delayed = classification_report(y_test, y_pred, output_dict=True)['1']['precision']
recall_delayed = classification_report(y_test, y_pred, output_dict=True)['1']['recall']

# Create styled results card
html_summary = f"""
<div style="
    background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
    color: white;
    padding: 25px;
    border-radius: 15px;
    margin: 20px 0;
    font-family: 'Segoe UI', Arial, sans-serif;
    box-shadow: 0 10px 30px rgba(0,0,0,0.3);
">
    <h3 style="margin: 0 0 20px 0; text-align: center; font-size: 24px;">
        🤖 Delivery Delay Prediction Model Results
    </h3>

    <div style="display: grid; grid-template-columns: repeat(auto-fit, minmax(180px, 1fr)); gap: 15px;">
        <div style="background: rgba(255,255,255,0.2); padding: 15px; border-radius: 10px; text-align: center;">
            <h4 style="margin: 0 0 8px 0; color: #FFD700;">Overall Accuracy</h4>
            <p style="font-size: 28px; margin: 0; font-weight: bold;">{accuracy:.1%}</p>
        </div>

        <div style="background: rgba(255,255,255,0.2); padding: 15px; border-radius: 10px; text-align: center;">
            <h4 style="margin: 0 0 8px 0; color: #90EE90;">Precision (Delayed)</h4>
            <p style="font-size: 28px; margin: 0; font-weight: bold;">{precision_delayed:.1%}</p>
        </div>

        <div style="background: rgba(255,255,255,0.2); padding: 15px; border-radius: 10px; text-align: center;">
            <h4 style="margin: 0 0 8px 0; color: #87CEEB;">Recall (Delayed)</h4>
            <p style="font-size: 28px; margin: 0; font-weight: bold;">{recall_delayed:.1%}</p>
        </div>

        <div style="background: rgba(255,255,255,0.2); padding: 15px; border-radius: 10px; text-align: center;">
            <h4 style="margin: 0 0 8px 0; color: #DDA0DD;">Dataset Size</h4>
            <p style="font-size: 28px; margin: 0; font-weight: bold;">{len(df_ml):,}</p>
        </div>
    </div>

    <div style="background: rgba(255,255,255,0.1); padding: 15px; border-radius: 10px; margin-top: 20px;">
        <h4 style="margin: 0 0 10px 0; color: #FFD700;">Key Insights:</h4>
        <ul style="margin: 0; padding-left: 20px; line-height: 1.6;">
            <li><strong>Most Important Feature:</strong> {feature_importance.iloc[0]['Feature']}</li>
            <li><strong>Test Set Size:</strong> {len(y_test):,} orders</li>
            <li><strong>Delayed Orders:</strong> {(y_test == 1).sum():,} ({(y_test == 1).mean():.1%})</li>
            <li><strong>On-Time Orders:</strong> {(y_test == 0).sum():,} ({(y_test == 0).mean():.1%})</li>
        </ul>
    </div>
</div>
"""

display(HTML(html_summary))
# Out:
# <div style="
#     background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
#     color: white;
#     padding: 25px;
#     border-radius: 15px;
#     margin: 20px 0;
#     font-family: 'Segoe UI', Arial, sans-serif;
#     box-shadow: 0 10px 30px rgba(0,0,0,0.3);
# ">
#     <h3 style="margin: 0 0 20px 0; text-align: center; font-size: 24px;">
#         🤖 Delivery Delay Prediction Model Results
#     </h3>
#
#     <div style="display: grid; grid-template-columns: repeat(auto-fit, minmax(180px, 1fr)); gap: 15px;">
#         <div style="background: rgba(255,255,255,0.2); padding: 15px; border-radius: 10px; text-align: center;">
#             <h4 style="margin: 0 0 8px 0; color: #FFD700;">Overall Accuracy</h4>
#             <p style="font-size: 28px; margin: 0; font-weight: bold;">97.9%</p>
#         </div>
#
#         <div style="background: rgba(255,255,255,0.2); padding: 15px; border-radius: 10px; text-align: center;">
# ...
